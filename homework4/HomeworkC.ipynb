# %% [markdown]
# - What is the observed value for cell A?
# - 1
# - What is the observed value for cell B?
# - 3
# - What is the observed value for cell C?
# - 2
# - What is the observed value for cell D?
# - 6
# - What is the observed value for cell E?
# - 3
# - What is the observed value for cell F?
# - 3
# - What is the observed value for cell G?
# - 7
# - What is the observed value for cell H?
# - 3
# - What is the observed value for cell I?
# - 8
# - What is the observed value for cell J?
# - 4
# - What is the observed value for cell K?
# - 2
# - What is the observed value for cell L?
# - 8
# - What is the observed value for cell M?
# - 12
# - What is the observed value for cell N?
# - 16
# - What is the observed value for cell O?
# - 22
# - What is the observed value for cell P?
# - 12
# - What is the observed value for cell Q?
# - 10
# - What is the observed value for cell R?
# - 11
# - What is the observed value for cell S?
# - 17
# - What is the observed value for cell T?
# - 50
# - What is the expected value for cell A? (round your answer to two decimal places)
# - 2.88
# - What is the expected value for cell B? (round your answer to two decimal places)
# - 2.4
# - What is the expected value for cell C? (round your answer to two decimal places)
# - 2.64
# - What is the expected value for cell D? (round your answer to two decimal places)
# - 4.08
# - What is the expected value for cell E? (round your answer to two decimal places)
# - 3.84
# - What is the expected value for cell F? (round your answer to two decimal places)
# - 3.2
# - What is the expected value for cell G? (round your answer to two decimal places)
# - 3.52
# - What is the expected value for cell H? (round your answer to two decimal places)
# - 5.44
# - What is the expected value for cell I? (round your answer to two decimal places)
# - 5.28
# - What is the expected value for cell J? (round your answer to two decimal places)
# - 4.4
# - What is the expected value for cell K? (round your answer to two decimal places)
# - 4.84
# - What is the expected value for cell L? (round your answer to two decimal places)
# - 7.48
# - What is the df for this problem?
# - 6
# - Calculate the Chi square value for the problem set. Round your answer to two decimal places. (Note: when completing your Chi square calculation table, round all intermediate calculations to two decimal places as well)
# - 10.31
# - Use the Chi square table to find the critical Chi square value for this problem. Provide the answer with three decimal places.
# - 12.592
# - Based on your findings can you reject the null hypothesis?
# - No
